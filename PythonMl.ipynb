# %%
 import tensorflow as tf

 from tensorflow.keras import datasets, layers, models
 import matplotlib.pyplot as plt

# %%
 (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

 # normalize pixel values to be between 0 and 1
 train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
 model = models.Sequential()
 model.add(layers.Conv2D(32, (3, 3), activation= 'relu', input_shape=(32, 32, 3)))
 model.add(layers.MaxPooling2D((2, 2)))
 model.add(layers.Conv2D(64, (3, 3), activation= 'relu'))
 model.add(layers.MaxPooling2D((2, 2)))
 model.add(layers.Conv2D(64, (3, 3), activation= 'relu'))

# %%
 model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 64)          36928
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
 model.add(layers.Flatten())
 model.add(layers.Dense(64, activation= 'relu'))
 model.add(layers.Dense(10))

# %%
 model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 64)          36928
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
 model.compile(optimizer='adam' ,
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])
 
 history = model.fit(train_images, train_labels, epochs=10,
                     validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.2161 - accuracy: 0.1501 - val_loss: 2.0073 - val_accuracy: 0.2370
# Epoch 2/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9852 - accuracy: 0.2545 - val_loss: 1.9534 - val_accuracy: 0.2589
# Epoch 3/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9542 - accuracy: 0.2547 - val_loss: 1.9294 - val_accuracy: 0.2663
# Epoch 4/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9409 - accuracy: 0.2561 - val_loss: 2.0216 - val_accuracy: 0.2446
# Epoch 5/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9382 - accuracy: 0.2567 - val_loss: 1.9304 - val_accuracy: 0.2608
# Epoch 6/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9287 - accuracy: 0.2593 - val_loss: 1.9133 - val_accuracy: 0.2774
# Epoch 7/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9256 - accuracy: 0.2637 - val_loss: 1.9181 - val_accuracy: 0.2655
# Epoch 8/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9250 - accuracy: 0.2631 - val_loss: 1.9116 - val_accuracy: 0.2686
# Epoch 9/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9182 - accuracy: 0.2649 - val_loss: 1.9456 - val_accuracy: 0.2634
# Epoch 10/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9161 - accuracy: 0.2625 - val_loss: 1.9145 - val_accuracy: 0.2712

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose = 2)
# Out:
# 313/313 - 0s - loss: 1.9145 - accuracy: 0.2712

# %%
 print(test_acc)
# Out:
# 0.2712000012397766
